# %%
import os
print os.getcwd()
os.chdir("/Users/edwsurewin/Dropbox/Berkeley MA/222/ipython")

from IPython.display import HTML
from numpy import nan
from numpy.random import randn
import numpy as np
np.set_printoptions(precision=2)
import pandas as pd
from pandas.core.common import adjoin
from pandas.io.data import DataReader
import pandas.util.testing as tm
tm.N = 10
import statsmodels.api as sm
import scipy.stats as stats
pd.options.display.max_columns=80
import requests
from statsmodels.graphics.api import qqplot
# Out:
# /Users/edwsurewin/Dropbox/Berkeley MA/222/STAT222-SP500

# %%
from pandas import DataFrame, read_csv
import pandas as pd #only needed to determine version number
print 'Pandas version ' + pd.__version__
# Out:
# Pandas version 0.13.1

# %%
import csv
df = pd.read_csv(("SP500.csv"),index_col=0,parse_dates=['Date']) #converts to numbers
df
# Out:
#                Open     High      Low    Close      Volume  Adj Close
# Date
# 2014-03-06  1874.18  1881.94  1874.18  1877.03  3360450000    1877.03
# 2014-03-05  1874.05  1876.53  1871.11  1873.81  3392990000    1873.81
# 2014-03-04  1849.23  1876.23  1849.23  1873.91  3765770000    1873.91
# 2014-03-03  1857.68  1857.68  1834.44  1845.73  3428220000    1845.73
# 2014-02-28  1855.12  1867.92  1847.67  1859.45  3917450000    1859.45
# 2014-02-27  1844.90  1854.53  1841.13  1854.29  3547460000    1854.29
# 2014-02-26  1845.79  1852.65  1840.66  1845.16  3716730000    1845.16
# 2014-02-25  1847.66  1852.91  1840.19  1845.12  3515560000    1845.12
# 2014-02-24  1836.78  1858.71  1836.78  1847.61  4014530000    1847.61
# 2014-02-21  1841.07  1846.13  1835.60  1836.25  3403880000    1836.25
# 2014-02-20  1829.24  1842.79  1824.58  1839.78  3404980000    1839.78
# 2014-02-19  1838.90  1847.50  1826.99  1828.75  3661570000    1828.75
# ...

# %%
oopen =df[['Open']]
oopen
# Out:
#                Open
# Date
# 2014-03-06  1874.18
# 2014-03-05  1874.05
# 2014-03-04  1849.23
# 2014-03-03  1857.68
# 2014-02-28  1855.12
# 2014-02-27  1844.90
# 2014-02-26  1845.79
# 2014-02-25  1847.66
# 2014-02-24  1836.78
# 2014-02-21  1841.07
# 2014-02-20  1829.24
# 2014-02-19  1838.90
# 2014-02-18  1839.03
# 2014-02-14  1828.46
# 2014-02-13  1814.82
# 2014-02-12  1820.12
# 2014-02-11  1800.45
# 2014-02-10  1796.20
# 2014-02-07  1776.01
# 2014-02-06  1752.99
# 2014-02-05  1753.38
# 2014-02-04  1743.82
# 2014-02-03  1782.68
# 2014-01-31  1790.88
# 2014-01-30  1777.17
# 2014-01-29  1790.15
# 2014-01-28  1783.00
# 2014-01-27  1791.03
# 2014-01-24  1826.96
# 2014-01-23  1842.29
# 2014-01-22  1844.71
# 2014-01-21  1841.05
# 2014-01-17  1844.23
# 2014-01-16  1847.99
# 2014-01-15  1840.52
# 2014-01-14  1821.36
# 2014-01-13  1841.26
# 2014-01-10  1840.06
# 2014-01-09  1839.00
# 2014-01-08  1837.90
# 2014-01-07  1828.71
# 2014-01-06  1832.31
# 2014-01-03  1833.21
# 2014-01-02  1845.86
# ...

# %%
from statsmodels import tsa
p=1
d=1
q=1
model1=tsa.arima_model.ARIMA(oopen, [p, d, q],freq='M').fit() #creates model

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ...
# Dep. Variable:                 D.Open   No. Observations:                16146
# Model:                 ARIMA(1, 1, 1)   Log Likelihood              -55296.043
# Method:                       css-mle   S.D. of innovations              7.432
# Date:                Sat, 15 Mar 2014   AIC                         110600.086
# Time:                        05:16:37   BIC                         110630.844
# Sample:                    03-05-2014   HQIC                        110610.254
#                          - 01-03-1950
# ...
#                    coef    std err          z      P>|z|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# const           -0.1149      0.050     -2.304      0.021        -0.213    -0.017
# ar.L1.D.Open     0.6959      0.050     13.887      0.000         0.598     0.794
# ...
