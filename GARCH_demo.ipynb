# %%
import rpy2 as rpy2

# %%
import pandas as pd
import pandas.rpy.common as rpy

# %%
# %load_ext rmagic

# %%
import os
print os.getcwd()
os.chdir("/Users/edwsurewin/Dropbox/Berkeley MA/222/STAT222-SP500")
# Out:
# /Users/edwsurewin/Dropbox/Berkeley MA/222/STAT222-SP500

# %%
att = pd.read_csv("SP500.csv")
print(att.head())
# Out:
#          Date     Open     High      Low    Close      Volume  Adj Close
# 0  2014-03-06  1874.18  1881.94  1874.18  1877.03  3360450000    1877.03
# 1  2014-03-05  1874.05  1876.53  1871.11  1873.81  3392990000    1873.81
# 2  2014-03-04  1849.23  1876.23  1849.23  1873.91  3765770000    1873.91
# 3  2014-03-03  1857.68  1857.68  1834.44  1845.73  3428220000    1845.73
# 4  2014-02-28  1855.12  1867.92  1847.67  1859.45  3917450000    1859.45
#
# [5 rows x 7 columns]

# %%
# %%R
# abc = read.csv("SP500.csv")
# print(mean(abc$Open))
# typeof(abc)
# Out:
# [1] 440.6348

# %%
# %%R
# library(stats)
# fit <- arima(ts(abc$Open),c(1,1,1))
# print(fit)
# Out:
# Call:
# arima(x = ts(abc$Open), order = c(1, 1, 1))
#
# Coefficients:
#          ar1      ma1
#       0.6867  -0.7318
# s.e.  0.0510   0.0478
#
# sigma^2 estimated as 55.25:  log likelihood = -55298.7,  aic = 110603.4

# %%
# %%R
# library(forecast)
# plot(forecast(object=fit, h=5000))
# Out:
# Loading required package: zoo
#
# Attaching package: ‘zoo’
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
# Loading required package: timeDate
# This is forecast 5.2

# %%
# %%R
# ## install.packages("tseries")
# library("tseries")
# dat <- diff(log(abc[,"Open"]))
# dat <- ts(dat[1:501])
# dat.garch <- garch(dat)
# summary(dat.garch)
# plot(dat.garch)
# Out:
# Hit <Return> to see next plot:
# Hit <Return> to see next plot:
# Hit <Return> to see next plot:
# Hit <Return> to see next plot:
#  ***** ESTIMATION WITH ANALYTICAL GRADIENT *****
#
#
#      I     INITIAL X(I)        D(I)
#
#      1     4.961745e-05     1.000e+00
#      2     5.000000e-02     1.000e+00
#      3     5.000000e-02     1.000e+00
#
#     IT   NF      F         RELDF    PRELDF    RELDX   STPPAR   D*STEP   NPRELDF
#      0    1 -2.200e+03
#      1   12 -2.200e+03  9.06e-06  1.96e-05  6.9e-06  9.0e+10  6.9e-07  8.84e+05
#      2   21 -2.200e+03  6.63e-05  1.43e-04  2.4e-01  2.0e+00  2.5e-02  3.65e-02
#      3   25 -2.201e+03  5.33e-04  1.39e-04  7.9e-01  0.0e+00  4.0e-01  2.13e-04
#      4   27 -2.201e+03  2.44e-04  2.05e-04  8.1e-02  2.0e+00  8.0e-02  7.17e-02
#      5   28 -2.202e+03  2.44e-04  4.63e-04  1.3e-01  2.0e+00  1.6e-01  4.17e+01
#      6   29 -2.203e+03  3.88e-04  1.21e-03  1.0e-01  1.9e+00  1.6e-01  2.57e-02
#      7   30 -2.203e+03  4.14e-05  1.63e-03  1.0e-01  1.9e+00  1.6e-01  1.46e-02
#      8   40 -2.203e+03  5.55e-05  8.46e-05  3.6e-07  4.3e+00  5.0e-07  6.50e-03
#      9   41 -2.203e+03  3.28e-07  2.41e-07  3.6e-07  2.0e+00  5.0e-07  1.48e-03
#     10   52 -2.203e+03 -1.55e-14  6.76e-15  5.5e-15  2.9e+05  7.6e-15  1.47e-03
#
#  ***** FALSE CONVERGENCE *****
#
#  FUNCTION    -2.203090e+03   RELDX        5.490e-15
#  FUNC. EVALS      52         GRAD. EVALS      10
#  PRELDF       6.757e-15      NPRELDF      1.471e-03
#
#      I      FINAL X(I)        D(I)          G(I)
#
#      1    1.363850e-05     1.000e+00    -1.966e+03
#      2    6.281351e-02     1.000e+00    -1.794e+01
#      3    6.894299e-01     1.000e+00    -1.006e+01
